# %%
import json 
import numpy as np
import pandas as pd
import re, nltk, spacy, string
nlp = spacy.load("en_core_web_sm")

import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
from collections import Counter
import swifter
from sklearn.feature_extraction.text import TfidfTransformer

# %matplotlib inline

from plotly.offline import plot
import plotly.graph_objects as go
import plotly.express as px

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from pprint import pprint

from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

import warnings
warnings.filterwarnings('ignore')

# %%
# Opening JSON file 
f = open(r'C:\Users\NikhilShinde\practice\Automatic Ticket Classification\complaints-2021-05-14_08_16.json')
 
data = json.load(f)
df=pd.json_normalize(data)

# %%
df
# Out:
#                     _index      _type      _id  _score   _source.tags  \
# 0      complaint-public-v2  complaint  3211475     0.0           None
# 1      complaint-public-v2  complaint  3229299     0.0  Servicemember
# 2      complaint-public-v2  complaint  3199379     0.0           None
# 3      complaint-public-v2  complaint  2673060     0.0           None
# 4      complaint-public-v2  complaint  3203545     0.0           None
# ...                    ...        ...      ...     ...            ...
# 78308  complaint-public-v2  complaint  3105617     0.0           None
# 78309  complaint-public-v2  complaint  3091984     0.0           None
# 78310  complaint-public-v2  complaint  3133355     0.0           None
# 78311  complaint-public-v2  complaint  3110963     0.0           None
# 78312  complaint-public-v2  complaint  2001189     0.0           None
#
#       _source.zip_code _source.complaint_id  \
# 0                90301              3211475
# 1                319XX              3229299
# 2                77069              3199379
# 3                48066              2673060
# 4                10473              3203545
# ...                ...                  ...
# 78308            08857              3105617
# 78309            934XX              3091984
# 78310            923XX              3133355
# 78311             None              3110963
# 78312             None              2001189
#
#                                            _source.issue  \
# 0                      Attempts to collect debt not owed
# 1                        Written notification about debt
# 2                     Other features, terms, or problems
# 3                         Trouble during payment process
# 4                                       Fees or interest
# ...                                                  ...
# 78308                                 Closing an account
# 78309                 Other features, terms, or problems
# 78310  Problem with a lender or other company chargin...
# 78311                 Other features, terms, or problems
# 78312                       Payment to acct not credited
#
#            _source.date_received _source.state  ...  \
# 0      2019-04-13T12:00:00-05:00            CA  ...
# 1      2019-05-01T12:00:00-05:00            GA  ...
# 2      2019-04-02T12:00:00-05:00            TX  ...
# 3      2017-09-13T12:00:00-05:00            MI  ...
# 4      2019-04-05T12:00:00-05:00            NY  ...
# ...                          ...           ...  ...
# 78308  2018-12-20T12:00:00-05:00            NJ  ...
# 78309  2018-12-05T12:00:00-05:00            CA  ...
# 78310  2019-01-25T12:00:00-05:00            CA  ...
# 78311  2018-12-27T12:00:00-05:00            PA  ...
# 78312  2016-07-06T12:00:00-05:00            MI  ...
#
#           _source.company_response       _source.company  \
# 0          Closed with explanation  JPMORGAN CHASE & CO.
# 1          Closed with explanation  JPMORGAN CHASE & CO.
# 2          Closed with explanation  JPMORGAN CHASE & CO.
# 3          Closed with explanation  JPMORGAN CHASE & CO.
# 4          Closed with explanation  JPMORGAN CHASE & CO.
# ...                            ...                   ...
# 78308      Closed with explanation  JPMORGAN CHASE & CO.
# 78309  Closed with monetary relief  JPMORGAN CHASE & CO.
# 78310      Closed with explanation  JPMORGAN CHASE & CO.
# 78311  Closed with monetary relief  JPMORGAN CHASE & CO.
# 78312      Closed with explanation  JPMORGAN CHASE & CO.
#
#       _source.submitted_via _source.date_sent_to_company  \
# 0                       Web    2019-04-13T12:00:00-05:00
# 1                       Web    2019-05-01T12:00:00-05:00
# 2                       Web    2019-04-02T12:00:00-05:00
# 3                       Web    2017-09-14T12:00:00-05:00
# 4                  Referral    2019-04-05T12:00:00-05:00
# ...                     ...                          ...
# 78308                   Web    2018-12-21T12:00:00-05:00
# 78309                   Web    2018-12-05T12:00:00-05:00
# 78310                   Web    2019-01-25T12:00:00-05:00
# 78311                   Web    2018-12-27T12:00:00-05:00
# 78312                   Web    2016-07-07T12:00:00-05:00
#
#       _source.company_public_response  \
# 0                                None
# 1                                None
# 2                                None
# 3                                None
# 4                                None
# ...                               ...
# 78308                            None
# 78309                            None
# 78310                            None
# 78311                            None
# 78312                            None
#
#                               _source.sub_product _source.timely  \
# 0                                Credit card debt            Yes
# 1                                Credit card debt            Yes
# 2      General-purpose credit card or charge card            Yes
# 3                      Conventional home mortgage            Yes
# 4      General-purpose credit card or charge card            Yes
# ...                                           ...            ...
# 78308                            Checking account            Yes
# 78309  General-purpose credit card or charge card            Yes
# 78310                            Checking account            Yes
# 78311  General-purpose credit card or charge card            Yes
# 78312                                        None            Yes
#
#                          _source.complaint_what_happened  \
# 0
# 1      Good morning my name is XXXX XXXX and I apprec...
# 2      I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3
# 4
# ...                                                  ...
# 78308
# 78309  On Wednesday, XX/XX/XXXX I called Chas, my XXX...
# 78310  I am not familiar with XXXX pay and did not un...
# 78311  I have had flawless credit for 30 yrs. I've ha...
# 78312  Roughly 10+ years ago I closed out my accounts...
#
#                                       _source.sub_issue  \
# 0                                     Debt is not yours
# 1      Didn't receive enough information to verify debt
# 2                 Problem with rewards from credit card
# 3                                                  None
# 4                             Charged too much interest
# ...                                                 ...
# 78308            Funds not received from closed account
# 78309                                     Other problem
# 78310                    Transaction was not authorized
# 78311                     Problem with balance transfer
# 78312                                              None
#
#       _source.consumer_consent_provided
# 0                  Consent not provided
# 1                      Consent provided
# 2                      Consent provided
# 3                  Consent not provided
# 4                                   N/A
# ...                                 ...
# 78308              Consent not provided
# 78309                  Consent provided
# 78310                  Consent provided
# 78311                  Consent provided
# 78312                  Consent provided
#
# [78313 rows x 22 columns]

# %%
#Assign new column names
df.rename(columns={'_source.complaint_what_happened':'complaints_what_happened', '_source.product':'tag'}, inplace=True)

# %%
df1=df[['complaints_what_happened',"tag"]]

# %%
# Function to clean the sent and remove all the unnecessary elements.
def clean_data_by_regex(sent):
    sent = sent.lower() # sent to lowercase
    sent = re.sub(r'x+((/xx)*/\d*\s*)|x*', '',sent) #Remove date
    sent = re.sub(r'\s\{\$\S*', '',sent) # Remove sent within curly braces
    sent = re.sub(r'\n', '', sent) # Remove line breaks
    sent = re.sub(r'\(\w*\)', '', sent) #remove sent within braces
    sent = re.sub(r'(\W\s)|(\W$)|(\W\d*)', ' ',sent) # Remove punctuation
    
    sent = re.sub(r'\d+\s', '', sent) #Remove other numerical values
    sent = re.sub(r' +', ' ',sent) #Remove unnecessary white spaces
    return sent

# %%
df['complaints'] = df['complaints_what_happened'].apply(clean_data_by_regex)
df.head()
# Out:
#                 _index      _type      _id  _score   _source.tags  \
# 0  complaint-public-v2  complaint  3211475     0.0           None
# 1  complaint-public-v2  complaint  3229299     0.0  Servicemember
# 2  complaint-public-v2  complaint  3199379     0.0           None
# 3  complaint-public-v2  complaint  2673060     0.0           None
# 4  complaint-public-v2  complaint  3203545     0.0           None
#
#   _source.zip_code _source.complaint_id                       _source.issue  \
# 0            90301              3211475   Attempts to collect debt not owed
# 1            319XX              3229299     Written notification about debt
# 2            77069              3199379  Other features, terms, or problems
# 3            48066              2673060      Trouble during payment process
# 4            10473              3203545                    Fees or interest
#
#        _source.date_received _source.state  ...       _source.company  \
# 0  2019-04-13T12:00:00-05:00            CA  ...  JPMORGAN CHASE & CO.
# 1  2019-05-01T12:00:00-05:00            GA  ...  JPMORGAN CHASE & CO.
# 2  2019-04-02T12:00:00-05:00            TX  ...  JPMORGAN CHASE & CO.
# 3  2017-09-13T12:00:00-05:00            MI  ...  JPMORGAN CHASE & CO.
# 4  2019-04-05T12:00:00-05:00            NY  ...  JPMORGAN CHASE & CO.
#
#   _source.submitted_via _source.date_sent_to_company  \
# 0                   Web    2019-04-13T12:00:00-05:00
# 1                   Web    2019-05-01T12:00:00-05:00
# 2                   Web    2019-04-02T12:00:00-05:00
# 3                   Web    2017-09-14T12:00:00-05:00
# 4              Referral    2019-04-05T12:00:00-05:00
#
#   _source.company_public_response                         _source.sub_product  \
# 0                            None                            Credit card debt
# 1                            None                            Credit card debt
# 2                            None  General-purpose credit card or charge card
# 3                            None                  Conventional home mortgage
# 4                            None  General-purpose credit card or charge card
#
#   _source.timely                           complaints_what_happened  \
# 0            Yes
# 1            Yes  Good morning my name is XXXX XXXX and I apprec...
# 2            Yes  I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3            Yes
# 4            Yes
#
#                                   _source.sub_issue  \
# 0                                 Debt is not yours
# 1  Didn't receive enough information to verify debt
# 2             Problem with rewards from credit card
# 3                                              None
# 4                         Charged too much interest
#
#   _source.consumer_consent_provided  \
# 0              Consent not provided
# 1                  Consent provided
# 2                  Consent provided
# 3              Consent not provided
# 4                               N/A
#
#                                           complaints
# 0
# 1  good morning my name is and i appreciate it if...
# 2  i upgraded my card in and was told by the agen...
# 3
# 4
#
# [5 rows x 23 columns]

# %%
# Function to Lemmatize the texts
def lemmatization(text):
    tokens = word_tokenize(text)
    wordnet_lemmetizer = WordNetLemmatizer()
    lemmatized = [wordnet_lemmetizer.lemmatize(token) for token in tokens]
    lemmatized_str = " ".join(lemmatized)
    return lemmatized_str

# %%
df
# Out:
#                     _index      _type      _id  _score   _source.tags  \
# 0      complaint-public-v2  complaint  3211475     0.0           None
# 1      complaint-public-v2  complaint  3229299     0.0  Servicemember
# 2      complaint-public-v2  complaint  3199379     0.0           None
# 3      complaint-public-v2  complaint  2673060     0.0           None
# 4      complaint-public-v2  complaint  3203545     0.0           None
# ...                    ...        ...      ...     ...            ...
# 78308  complaint-public-v2  complaint  3105617     0.0           None
# 78309  complaint-public-v2  complaint  3091984     0.0           None
# 78310  complaint-public-v2  complaint  3133355     0.0           None
# 78311  complaint-public-v2  complaint  3110963     0.0           None
# 78312  complaint-public-v2  complaint  2001189     0.0           None
#
#       _source.zip_code _source.complaint_id  \
# 0                90301              3211475
# 1                319XX              3229299
# 2                77069              3199379
# 3                48066              2673060
# 4                10473              3203545
# ...                ...                  ...
# 78308            08857              3105617
# 78309            934XX              3091984
# 78310            923XX              3133355
# 78311             None              3110963
# 78312             None              2001189
#
#                                            _source.issue  \
# 0                      Attempts to collect debt not owed
# 1                        Written notification about debt
# 2                     Other features, terms, or problems
# 3                         Trouble during payment process
# 4                                       Fees or interest
# ...                                                  ...
# 78308                                 Closing an account
# 78309                 Other features, terms, or problems
# 78310  Problem with a lender or other company chargin...
# 78311                 Other features, terms, or problems
# 78312                       Payment to acct not credited
#
#            _source.date_received _source.state  ...       _source.company  \
# 0      2019-04-13T12:00:00-05:00            CA  ...  JPMORGAN CHASE & CO.
# 1      2019-05-01T12:00:00-05:00            GA  ...  JPMORGAN CHASE & CO.
# 2      2019-04-02T12:00:00-05:00            TX  ...  JPMORGAN CHASE & CO.
# 3      2017-09-13T12:00:00-05:00            MI  ...  JPMORGAN CHASE & CO.
# 4      2019-04-05T12:00:00-05:00            NY  ...  JPMORGAN CHASE & CO.
# ...                          ...           ...  ...                   ...
# 78308  2018-12-20T12:00:00-05:00            NJ  ...  JPMORGAN CHASE & CO.
# 78309  2018-12-05T12:00:00-05:00            CA  ...  JPMORGAN CHASE & CO.
# 78310  2019-01-25T12:00:00-05:00            CA  ...  JPMORGAN CHASE & CO.
# 78311  2018-12-27T12:00:00-05:00            PA  ...  JPMORGAN CHASE & CO.
# 78312  2016-07-06T12:00:00-05:00            MI  ...  JPMORGAN CHASE & CO.
#
#       _source.submitted_via _source.date_sent_to_company  \
# 0                       Web    2019-04-13T12:00:00-05:00
# 1                       Web    2019-05-01T12:00:00-05:00
# 2                       Web    2019-04-02T12:00:00-05:00
# 3                       Web    2017-09-14T12:00:00-05:00
# 4                  Referral    2019-04-05T12:00:00-05:00
# ...                     ...                          ...
# 78308                   Web    2018-12-21T12:00:00-05:00
# 78309                   Web    2018-12-05T12:00:00-05:00
# 78310                   Web    2019-01-25T12:00:00-05:00
# 78311                   Web    2018-12-27T12:00:00-05:00
# 78312                   Web    2016-07-07T12:00:00-05:00
#
#       _source.company_public_response  \
# 0                                None
# 1                                None
# 2                                None
# 3                                None
# 4                                None
# ...                               ...
# 78308                            None
# 78309                            None
# 78310                            None
# 78311                            None
# 78312                            None
#
#                               _source.sub_product _source.timely  \
# 0                                Credit card debt            Yes
# 1                                Credit card debt            Yes
# 2      General-purpose credit card or charge card            Yes
# 3                      Conventional home mortgage            Yes
# 4      General-purpose credit card or charge card            Yes
# ...                                           ...            ...
# 78308                            Checking account            Yes
# 78309  General-purpose credit card or charge card            Yes
# 78310                            Checking account            Yes
# 78311  General-purpose credit card or charge card            Yes
# 78312                                        None            Yes
#
#                                 complaints_what_happened  \
# 0
# 1      Good morning my name is XXXX XXXX and I apprec...
# 2      I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3
# 4
# ...                                                  ...
# 78308
# 78309  On Wednesday, XX/XX/XXXX I called Chas, my XXX...
# 78310  I am not familiar with XXXX pay and did not un...
# 78311  I have had flawless credit for 30 yrs. I've ha...
# 78312  Roughly 10+ years ago I closed out my accounts...
#
#                                       _source.sub_issue  \
# 0                                     Debt is not yours
# 1      Didn't receive enough information to verify debt
# 2                 Problem with rewards from credit card
# 3                                                  None
# 4                             Charged too much interest
# ...                                                 ...
# 78308            Funds not received from closed account
# 78309                                     Other problem
# 78310                    Transaction was not authorized
# 78311                     Problem with balance transfer
# 78312                                              None
#
#       _source.consumer_consent_provided  \
# 0                  Consent not provided
# 1                      Consent provided
# 2                      Consent provided
# 3                  Consent not provided
# 4                                   N/A
# ...                                 ...
# 78308              Consent not provided
# 78309                  Consent provided
# 78310                  Consent provided
# 78311                  Consent provided
# 78312                  Consent provided
#
#                                               complaints
# 0
# 1      good morning my name is and i appreciate it if...
# 2      i upgraded my card in and was told by the agen...
# 3
# 4
# ...                                                  ...
# 78308
# 78309  on wednesday i called chas my visa credit card...
# 78310  i am not familiar with pay and did not underst...
# 78311  i have had flawless credit for yrs i ve had ch...
# 78312  roughly years ago i closed out my accounts wit...
#
# [78313 rows x 23 columns]

# %%
df_clean = pd.DataFrame({'complaints':df['complaints'], 'lemmatized':df['complaints'].apply(lemmatization)})

# %%
def get_pos_tags(text):
    nn_words = []
    doc = nlp(text)
    for tok in doc:
        if(tok.tag_ == 'NN'):
            nn_words.append(tok.lemma_)
    nn_words_str = " ".join(nn_words)
    return nn_words_str


df_clean["complaint_POS_removed"] =  df_clean.swifter.apply(lambda x: get_pos_tags(x['lemmatized']), axis=1)
# Out:
# Pandas Apply:   0%|          | 0/78313 [00:00<?, ?it/s]

# %%
df_clean
# Out:
#                                               complaints  \
# 0
# 1      good morning my name is and i appreciate it if...
# 2      i upgraded my card in and was told by the agen...
# 3
# 4
# ...                                                  ...
# 78308
# 78309  on wednesday i called chas my visa credit card...
# 78310  i am not familiar with pay and did not underst...
# 78311  i have had flawless credit for yrs i ve had ch...
# 78312  roughly years ago i closed out my accounts wit...
#
#                                               lemmatized  \
# 0
# 1      good morning my name is and i appreciate it if...
# 2      i upgraded my card in and wa told by the agent...
# 3
# 4
# ...                                                  ...
# 78308
# 78309  on wednesday i called chas my visa credit card...
# 78310  i am not familiar with pay and did not underst...
# 78311  i have had flawless credit for yr i ve had cha...
# 78312  roughly year ago i closed out my account with ...
#
#                                    complaint_POS_removed
# 0
# 1      morning name stop debt verification statement ...
# 2      card agent anniversary date agent information ...
# 3
# 4
# ...                                                  ...
# 78308
# 78309  visa credit card provider claim purchase prote...
# 78310  pay risk consumer chase bank app chase year ba...
# 78311  credit yr chase credit card chase freedom prob...
# 78312  year account order line credit account payment...
#
# [78313 rows x 3 columns]

# %%
plt.figure(figsize=(10,6))
doc_lens = [len(d) for d in df_clean.complaint_POS_removed]
plt.hist(doc_lens, bins = 100)
plt.ylabel('Number of Complaints')
plt.xlabel('character length');

# %%
# Top 20 words frequency wise wordcloud
wordcloud = WordCloud(max_words=20, random_state=1, stopwords=set(STOPWORDS))
wordcloud.generate(str(df_clean['complaint_POS_removed']))
plt.figure(figsize=(12,12))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#Removing -PRON- from the text corpus
df_clean['Complaint_clean'] = df_clean['complaint_POS_removed'].str.replace('-PRON-', '')
df_clean
# Out:
#                                               complaints  \
# 0
# 1      good morning my name is and i appreciate it if...
# 2      i upgraded my card in and was told by the agen...
# 3
# 4
# ...                                                  ...
# 78308
# 78309  on wednesday i called chas my visa credit card...
# 78310  i am not familiar with pay and did not underst...
# 78311  i have had flawless credit for yrs i ve had ch...
# 78312  roughly years ago i closed out my accounts wit...
#
#                                               lemmatized  \
# 0
# 1      good morning my name is and i appreciate it if...
# 2      i upgraded my card in and wa told by the agent...
# 3
# 4
# ...                                                  ...
# 78308
# 78309  on wednesday i called chas my visa credit card...
# 78310  i am not familiar with pay and did not underst...
# 78311  i have had flawless credit for yr i ve had cha...
# 78312  roughly year ago i closed out my account with ...
#
#                                    complaint_POS_removed  \
# 0
# 1      morning name stop debt verification statement ...
# 2      card agent anniversary date agent information ...
# 3
# 4
# ...                                                  ...
# 78308
# 78309  visa credit card provider claim purchase prote...
# 78310  pay risk consumer chase bank app chase year ba...
# 78311  credit yr chase credit card chase freedom prob...
# 78312  year account order line credit account payment...
#
#                                          Complaint_clean
# 0
# 1      morning name stop debt verification statement ...
# 2      card agent anniversary date agent information ...
# 3
# 4
# ...                                                  ...
# 78308
# 78309  visa credit card provider claim purchase prote...
# 78310  pay risk consumer chase bank app chase year ba...
# 78311  credit yr chase credit card chase freedom prob...
# 78312  year account order line credit account payment...
#
# [78313 rows x 4 columns]

# %%
def top_grams(grams):
    c_vec = CountVectorizer(stop_words=stopwords.words('english'), ngram_range=(grams,grams))
    grams = c_vec.fit_transform(df_clean['complaints'])
    count_values = grams.toarray().sum(axis=0)
    vocab = c_vec.vocabulary_
    df_ngram = pd.DataFrame(sorted([(count_values[i],k) for k,i in vocab.items()], reverse=True)
            ).rename(columns={0: 'frequency', 1:'unigram'})
    return df_ngram

# %%
df_unigram = top_grams(1)

# %%
#Write your code here to initialise the TfidfVectorizer 
tfidf = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')

# %%
#Write your code here to create the Document Term Matrix by transforming the complaints column present in df_clean.
dtm = tfidf.fit_transform(df_clean['complaints'])

# %%
from sklearn.decomposition import NMF

# %%
#Load your nmf_model with the n_components i.e 5
num_topics = 5

#keep the random_state =40
nmf_model = NMF(random_state=40, n_components=num_topics)

# %%
nmf_model.fit(dtm)
len(tfidf.get_feature_names())
# Out:
# 14991

# %%
#Print the Top15 words for each of the topics
words = np.array(tfidf.get_feature_names())
topic_words_df = pd.DataFrame(np.zeros((num_topics, 15)), index=[f'Topic {i + 1}' for i in range(num_topics)],
                           columns=[f'Word {i + 1}' for i in range(15)]).astype(str)

for i in range(num_topics):
    ix = nmf_model.components_[i].argsort()[::-1][:15]
    topic_words_df.iloc[i] = words[ix]

topic_words_df
# Out:
#           Word 1 Word 2    Word 3   Word 4        Word 5 Word 6    Word 7  \
# Topic 1    chase   card    charge  charges        called   told   dispute
# Topic 2   credit   card    report  inquiry         chase  cards      hard
# Topic 3     loan  chase  mortgage     home  modification   bank  property
# Topic 4  account   bank     chase    check         money  funds    closed
# Topic 5  payment   late  payments  balance          paid    pay     month
#
#            Word 8     Word 9      Word 10    Word 11   Word 12      Word 13  \
# Topic 1       did   received        fraud       said     claim  transaction
# Topic 2     score  inquiries    reporting   accounts   account       closed
# Topic 3  payments      years  foreclosure     morgan     house           jp
# Topic 4  checking    deposit       branch       told  accounts    deposited
# Topic 5      fees        fee         make  statement      time         auto
#
#          Word 14  Word 15
# Topic 1    phone   number
# Topic 2    limit  applied
# Topic 3     sale     rate
# Topic 4   opened     open
# Topic 5  monthly     days

# %%
#Create the best topic for each complaint in terms of integer value 0,1,2,3 & 4
topic_results = nmf_model.transform(dtm)
topic_results.argmax(axis=1)
# Out:
# array([0, 2, 0, ..., 0, 4, 4], dtype=int64)

# %%
df_clean['Topic'] = topic_results.argmax(axis=1)

# %%
# Print the first 5 Complaint for each of the Topics
First5_comp=df_clean.groupby('Topic').head(5)
First5_comp.sort_values('Topic')
# Out:
#                                             complaints  \
# 0
# 2    i upgraded my card in and was told by the agen...
# 3
# 4
# 5
# 26   i have reached out to several times in attempt...
# 15                       can you please remove inquiry
# 23   i have a chase credit card which is incorrectl...
# 10   chase card was reported on however fraudulent ...
# 11   on while trying to book a ticket i came across...
# 86   a student loan with chase bank they sold there...
# 81   i bought a new on from in i paid the loan in b...
# 73   i have wired through one of chase branches in ...
# 57   i have been trying to do a loan modification w...
# 1    good morning my name is and i appreciate it if...
# 14   my grand son give me check for i deposit it in...
# 35   i opened the saving account for the bonus i wa...
# 24      mishandling of this account by chase auto and
# 17   with out notice j p morgan chase restricted my...
# 27   i opened an account with chase bank on and use...
# 58   i made a purchase of on i made payments of on ...
# 115  multiple times with the latest being chase has...
# 20   during the summer months i eperience a decline...
# 82   i recently called to ask chase bank why they r...
# 141  action taken by the company between the dates ...
#
#                                             lemmatized  \
# 0
# 2    i upgraded my card in and wa told by the agent...
# 3
# 4
# 5
# 26   i have reached out to several time in attempt ...
# 15                       can you please remove inquiry
# 23   i have a chase credit card which is incorrectl...
# 10   chase card wa reported on however fraudulent a...
# 11   on while trying to book a ticket i came across...
# 86   a student loan with chase bank they sold there...
# 81   i bought a new on from in i paid the loan in b...
# 73   i have wired through one of chase branch in th...
# 57   i have been trying to do a loan modification w...
# 1    good morning my name is and i appreciate it if...
# 14   my grand son give me check for i deposit it in...
# 35   i opened the saving account for the bonus i wa...
# 24       mishandling of this account by chase auto and
# 17   with out notice j p morgan chase restricted my...
# 27   i opened an account with chase bank on and use...
# 58   i made a purchase of on i made payment of on a...
# 115  multiple time with the latest being chase ha m...
# 20   during the summer month i eperience a decline ...
# 82   i recently called to ask chase bank why they r...
# 141  action taken by the company between the date o...
#
#                                  complaint_POS_removed  \
# 0
# 2    card agent anniversary date agent information ...
# 3
# 4
# 5
# 26   time attempt inquiry creditor inquiry report a...
# 15                                             inquiry
# 23       chase credit card credit report company issue
# 10   chase card application identity consent servic...
# 11   ticket offer ticket reward card information of...
# 86   student loan account account attempt work depa...
# 81   loan chase title chase time resolution time no...
# 73   chase branch eact reinstatement amount order f...
# 57           loan modification chase runaround payment
# 1    morning name stop debt verification statement ...
# 14   son check chase account fund chase bank accoun...
# 35   saving account bonus bonus auto transfer trans...
# 24                                  account chase auto
# 17   notice chase account debit card branch custome...
# 27   account code bonus term everything account dep...
# 58   purchase payment payment closing date statemen...
# 115  time being chase order credit debit account fe...
# 20   summer month decline income employment month p...
# 82   chase bank credit bureau day payment info bill...
# 141  action company date individual group chase cla...
#
#                                        Complaint_clean  Topic
# 0                                                           0
# 2    card agent anniversary date agent information ...      0
# 3                                                           0
# 4                                                           0
# 5                                                           0
# 26   time attempt inquiry creditor inquiry report a...      1
# 15                                             inquiry      1
# 23       chase credit card credit report company issue      1
# 10   chase card application identity consent servic...      1
# 11   ticket offer ticket reward card information of...      1
# 86   student loan account account attempt work depa...      2
# 81   loan chase title chase time resolution time no...      2
# 73   chase branch eact reinstatement amount order f...      2
# 57           loan modification chase runaround payment      2
# 1    morning name stop debt verification statement ...      2
# 14   son check chase account fund chase bank accoun...      3
# 35   saving account bonus bonus auto transfer trans...      3
# 24                                  account chase auto      3
# 17   notice chase account debit card branch custome...      3
# 27   account code bonus term everything account dep...      3
# 58   purchase payment payment closing date statemen...      4
# 115  time being chase order credit debit account fe...      4
# 20   summer month decline income employment month p...      4
# 82   chase bank credit bureau day payment info bill...      4
# 141  action company date individual group chase cla...      4

# %%
# Create the dictionary of Topic names and Topics
Topic_names = {0:'Account Services', 1:'Others', 2:'Mortgage/Loan', 3:'Credit card or prepaid card', 4:'Theft/Dispute Reporting'}

# Replace Topics with Topic Names
df_clean['Topic'] = df_clean['Topic'].map(Topic_names)

# %%
# Keep the columns"complaint_what_happened" & "Topic" only in the new dataframe --> training_data
training_data = df_clean.drop(['lemmatized', 'complaint_POS_removed', 'Complaint_clean'], axis=1)

# %%
# Write your code to get the Vector count
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(training_data.complaints)

# Write your code here to transform the word vector to tf-idf
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report

# %%
# Split data into train and test
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf, training_data.Topic, test_size=0.1, random_state=24)

# %% [markdown]
# # Classifiers

# %%
# Logistic Regression
lr = LogisticRegression().fit(X_train, y_train)
predicted = lr.predict(X_test)

print(classification_report(y_true=y_test, y_pred=predicted))
# Out:
#                              precision    recall  f1-score   support
#
#            Account Services       0.98      0.99      0.99      6287
# Credit card or prepaid card       0.93      0.90      0.92       491
#               Mortgage/Loan       0.95      0.89      0.92       360
#                      Others       0.92      0.91      0.92       452
#     Theft/Dispute Reporting       0.97      0.85      0.90       242
#
#                    accuracy                           0.97      7832
#                   macro avg       0.95      0.91      0.93      7832
#                weighted avg       0.97      0.97      0.97      7832

# %%
# Decision tree classifier
dt = DecisionTreeClassifier().fit(X_train, y_train)
predicted = dt.predict(X_test)

print(classification_report(y_pred=predicted, y_true=y_test))
# Out:
#                              precision    recall  f1-score   support
#
#            Account Services       0.98      0.98      0.98      6287
# Credit card or prepaid card       0.84      0.81      0.82       491
#               Mortgage/Loan       0.79      0.82      0.80       360
#                      Others       0.84      0.86      0.85       452
#     Theft/Dispute Reporting       0.72      0.68      0.70       242
#
#                    accuracy                           0.95      7832
#                   macro avg       0.84      0.83      0.83      7832
#                weighted avg       0.95      0.95      0.95      7832

# %%
rfc = RandomForestClassifier(max_depth=10)
rfc.fit(X_train, y_train)
predicted = rfc.predict(X_test)

print(classification_report(y_pred=predicted, y_true=y_test))
# Out:
#                              precision    recall  f1-score   support
#
#            Account Services       0.87      1.00      0.93      6287
# Credit card or prepaid card       0.82      0.46      0.59       491
#               Mortgage/Loan       0.86      0.54      0.66       360
#                      Others       0.89      0.24      0.38       452
#     Theft/Dispute Reporting       1.00      0.01      0.02       242
#
#                    accuracy                           0.87      7832
#                   macro avg       0.89      0.45      0.52      7832
#                weighted avg       0.87      0.87      0.84      7832

# %%
nb = GaussianNB().fit(X_train.toarray(), y_train)
predicted = nb.predict(X_test.toarray())

print(classification_report(y_pred=predicted, y_true=y_test))
# Out:
#                              precision    recall  f1-score   support
#
#            Account Services       0.53      0.02      0.05      6287
# Credit card or prepaid card       0.37      0.24      0.29       491
#               Mortgage/Loan       0.44      0.40      0.42       360
#                      Others       0.35      0.34      0.34       452
#     Theft/Dispute Reporting       0.02      0.50      0.04       242
#
#                    accuracy                           0.09      7832
#                   macro avg       0.34      0.30      0.23      7832
#                weighted avg       0.49      0.09      0.10      7832

# %% [markdown]
# * best model here is Logistic Regression we are not using any Neural networks.
